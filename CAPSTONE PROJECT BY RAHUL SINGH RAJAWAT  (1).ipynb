# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("CAR DETAILS.csv")   # importing the dataset
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %% [markdown]
# #### Checking columns name in dataset

# %%
df.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner'],
#       dtype='object')

# %% [markdown]
# ### Shape of Dataset

# %%
df.shape
# Out:
# (4340, 8)

# %% [markdown]
# ### To see null values in dataset

# %%
df.isnull().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# dtype: int64

# %% [markdown]
# ### Datatypes of columns

# %%
df.dtypes
# Out:
# name             object
# year              int64
# selling_price     int64
# km_driven         int64
# fuel             object
# seller_type      object
# transmission     object
# owner            object
# dtype: object

# %% [markdown]
# ### See the unique values containing columns

# %%
df[['fuel','seller_type','transmission','owner']].nunique()
# Out:
# fuel            5
# seller_type     3
# transmission    2
# owner           5
# dtype: int64

# %% [markdown]
# ## Arranging all years

# %%
print(sorted(df.year.unique()))
# Out:
# [1992, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]

# %%
unique_name = df.name.unique()
print(unique_name.sum())
# Out:
# Maruti 800 ACMaruti Wagon R LXI MinorHyundai Verna 1.6 SXDatsun RediGO T OptionHonda Amaze VX i-DTECMaruti Alto LX BSIIIHyundai Xcent 1.2 Kappa STata Indigo Grand PetrolHyundai Creta 1.6 VTVT SMaruti Celerio Green VXIChevrolet Sail 1.2 BaseToyota Corolla Altis 1.8 VL CVTMaruti Ciaz VXi PlusHyundai Venue SX Opt DieselChevrolet Enjoy TCDi LTZ 7 SeaterJaguar XF 2.2 Litre LuxuryMercedes-Benz New C-Class 220 CDI ATMaruti Vitara Brezza ZDi Plus AMTAudi Q5 2.0 TDIHonda City V MTTata Tigor 1.2 Revotron XTAudi A6 2.0 TDI  Design EditionMercedes-Benz New C-Class C 220 CDI AvantgardeSkoda Superb Ambition 2.0 TDI CR ATToyota Corolla Altis G ATToyota Innova 2.5 G (Diesel) 7 SeaterJeep Compass 1.4 Sport Plus BSIVMercedes-Benz E-Class E 200 CGI EleganceHyundai i10 Magna 1.1LBMW 3 Series 320d Sport LineAudi Q7 35 TDI Quattro PremiumHyundai Elantra CRDi SMahindra Scorpio 1.99 S10Honda City i DTEC VMaruti Wagon R VXI BS IV with ABSMaruti Wagon R VXI BS IVMahindra Scorpio LXHyundai Santro Xing GLSHyundai Grand i10 1.2 Kappa AstaMaruti Alto LXiMaruti Swift Dzire VDI OptionalMaruti Eeco 5 Seater AC BSIVHyundai i20 Sportz 1.4 CRDiMaruti Omni Maruti Omni MPI STD BSIII 5-STR W/ IMMOBILISERMaruti Swift ZDi BSIVHyundai i20 2015-2017 Sportz Option 1.4 CRDiMahindra Jeep CL 500 MDIHonda City i DTEC VXTata Indica DLSHyundai EON Magna PlusToyota Etios GDChevrolet Tavera Neo LS B3 - 7(C) seats BSIIIToyota Corolla Altis Diesel D4DGMahindra Scorpio 1.99 S6 PlusTata Indigo Classic DicorToyota Innova 2.5 V Diesel 8-seaterTata Indica Vista Quadrajet LSMaruti Swift 1.3 VXiFord EcoSport 1.5 Diesel Titanium BSIVMaruti Ciaz 1.3 DeltaHonda Civic 1.8 V ATHyundai i10 Sportz 1.2Skoda Rapid 1.5 TDI EleganceHyundai Getz GLSNissan Terrano XLHyundai Grand i10 CRDi SportzHyundai Elite i20 Diesel EraHonda Amaze S i-VTECHonda Brio S MTHyundai Creta 1.6 SX OptionMercedes-Benz S-Class S 350d Connoisseurs EditionMahindra XUV500 W8 2WDRenault Duster 85PS Diesel RxL OptionalHyundai Santro Xing XOMahindra Bolero 2011-2019 SLEAudi A6 2.0 TDI Premium PlusFiat Avventura MULTIJET EmotionAudi A8 4.2 TDIDatsun RediGO 1.0 SVolkswagen Jetta 1.4 TSI ComfortlineAudi A4 2.0 TDI 177 Bhp Premium PlusMercedes-Benz E-Class Exclusive E 200 BSIVBMW X1 sDrive 20d xLineVolvo V40 D3 R DesignMaruti SX4 Zxi BSIIIBMW 7 Series 730LdMahindra Bolero Power Plus SLXHyundai Sonata CRDi M/TNissan Micra Active XV PetrolMahindra Xylo D4Hyundai Elite i20 Sportz Plus Dual Tone BSIVRenault KWID RXTMahindra Xylo E4 BS IIIMaruti SX4 ZXI MT BSIVHyundai Creta 1.4 CRDi SMaruti Swift Dzire VDIHyundai Verna 1.6 VTVT AT S OptionMahindra Scorpio LX BSIVMaruti SX4 Vxi BSIIIMaruti Ertiga VDIChevrolet Beat DieselMaruti Zen LXMaruti Baleno Delta 1.2Maruti Swift Vdi BSIIITata Nano Lx BSIVToyota Innova 2.5 GX (Diesel) 8 SeaterMaruti Ertiga SHVS VDIHyundai Creta 1.6 CRDi SXHonda Amaze S i-VtechTata Indica Vista Aqua 1.4 TDIChevrolet Tavera Neo 2 LS B4 7 Str BSIIIChevrolet Cruze LTZFord Figo Aspire 1.2 Ti-VCT Titanium PlusFord EcoSport 1.5 Diesel Titanium Plus BSIVHyundai i10 Sportz 1.1LMaruti 800 StdChevrolet Spark 1.0 LSHyundai EON Era PlusTata Indica Vista Aqua TDI BSIIIHyundai Santro LP zipPlusTata Bolt Quadrajet XEMaruti 800 AC BSIIIHyundai i20 Magna 1.2Hyundai i20 1.2 AstaMaruti Ciaz VDi PlusHyundai i20 Asta 1.4 CRDiHyundai Santro LEMaruti Vitara Brezza VDiHyundai Santro Xing XL eRLX Euro IIIHyundai Getz 1.3 GLSMahindra Quanto C8Chevrolet Tavera Neo 3 LS 7 C BSIIIMaruti Wagon R DUO LPGMaruti Wagon R LXIChevrolet Enjoy 1.3 TCDi LS 8Honda City i VTEC SVJaguar XJ 5.0 L V8 SuperchargedHonda Brio E MTMaruti Swift VVT ZXITata Indigo CR4Hyundai i10 Asta ATChevrolet Beat LTMaruti Swift VDI BSIVRenault Duster 110PS Diesel RxZHyundai Santro Xing XGMaruti Swift Dzire ZXI PlusMaruti Alto K10 LXI CNGMaruti 800 Std BSIITata Nano LX SESkoda Rapid 1.6 MPI Ambition With Alloy WheelMaruti Alto K10 VXIMaruti Ciaz 1.4 DeltaMaruti Alto LXHyundai i20 AstaTata Nexon 1.2 Revotron XMMaruti Zen DVolkswagen Vento Celeste 1.5 TDI Highline ATMaruti Eeco 7 S ...

# %% [markdown]
# ## Checking every column unique values

# %%
df['fuel'].unique()
# Out:
# array(['Petrol', 'Diesel', 'CNG', 'LPG', 'Electric'], dtype=object)

# %%
print(df.seller_type.unique())
# Out:
# ['Individual' 'Dealer' 'Trustmark Dealer']

# %%
df.transmission.unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
print(df.owner.unique())
# Out:
# ['First Owner' 'Second Owner' 'Fourth & Above Owner' 'Third Owner'
#  'Test Drive Car']

# %% [markdown]
# ### See statistics overview of dataset

# %%
df.describe()
# Out:
#               year  selling_price      km_driven
# count  4340.000000   4.340000e+03    4340.000000
# mean   2013.090783   5.041273e+05   66215.777419
# std       4.215344   5.785487e+05   46644.102194
# min    1992.000000   2.000000e+04       1.000000
# 25%    2011.000000   2.087498e+05   35000.000000
# 50%    2014.000000   3.500000e+05   60000.000000
# 75%    2016.000000   6.000000e+05   90000.000000
# max    2020.000000   8.900000e+06  806599.000000

# %%
df.describe(include='all')
# Out:
#                           name         year  selling_price      km_driven  \
# count                     4340  4340.000000   4.340000e+03    4340.000000
# unique                    1491          NaN            NaN            NaN
# top     Maruti Swift Dzire VDI          NaN            NaN            NaN
# freq                        69          NaN            NaN            NaN
# mean                       NaN  2013.090783   5.041273e+05   66215.777419
# std                        NaN     4.215344   5.785487e+05   46644.102194
# min                        NaN  1992.000000   2.000000e+04       1.000000
# 25%                        NaN  2011.000000   2.087498e+05   35000.000000
# 50%                        NaN  2014.000000   3.500000e+05   60000.000000
# 75%                        NaN  2016.000000   6.000000e+05   90000.000000
# max                        NaN  2020.000000   8.900000e+06  806599.000000
#
#           fuel seller_type transmission        owner
# count     4340        4340         4340         4340
# unique       5           3            2            5
# top     Diesel  Individual       Manual  First Owner
# freq      2153        3244         3892         2832
# mean       NaN         NaN          NaN          NaN
# std        NaN         NaN          NaN          NaN
# min        NaN         NaN          NaN          NaN
# 25%        NaN         NaN          NaN          NaN
# 50%        NaN         NaN          NaN          NaN
# 75%        NaN         NaN          NaN          NaN
# max        NaN         NaN          NaN          NaN

# %% [markdown]
# ## Checking the Duplicated values

# %%
df.duplicated().sum()
# Out:
# 763

# %% [markdown]
# #### There are 763 duplicates values but we don't delete it from dataset because a single car is used many customer.

# %% [markdown]
# #                      DATA ANALYSIS

# %% [markdown]
# ## Extracting brand name and car model name from name column

# %%
df['brand_name'] = df['name'].str.split().str[0]
df['car_name'] = df['name'].str.split().str[1]

# %% [markdown]
# ## Removing the name column

# %%
df.drop('name', axis=1, inplace=True)
df.head()
# Out:
#    year  selling_price  km_driven    fuel seller_type transmission  \
# 0  2007          60000      70000  Petrol  Individual       Manual
# 1  2007         135000      50000  Petrol  Individual       Manual
# 2  2012         600000     100000  Diesel  Individual       Manual
# 3  2017         250000      46000  Petrol  Individual       Manual
# 4  2014         450000     141000  Diesel  Individual       Manual
#
#           owner brand_name car_name
# 0   First Owner     Maruti      800
# 1   First Owner     Maruti    Wagon
# 2   First Owner    Hyundai    Verna
# 3   First Owner     Datsun   RediGO
# 4  Second Owner      Honda    Amaze

# %% [markdown]
# ## Moving the brand_name and car_name to the left side of table

# %%
brand = df['brand_name']
car = df['car_name']
df.drop(['brand_name', 'car_name'], axis=1, inplace = True)
df.insert(0,'brand_name', brand)
df.insert(1, 'car_name', car)
df.head()
# Out:
#   brand_name car_name  year  selling_price  km_driven    fuel seller_type  \
# 0     Maruti      800  2007          60000      70000  Petrol  Individual
# 1     Maruti    Wagon  2007         135000      50000  Petrol  Individual
# 2    Hyundai    Verna  2012         600000     100000  Diesel  Individual
# 3     Datsun   RediGO  2017         250000      46000  Petrol  Individual
# 4      Honda    Amaze  2014         450000     141000  Diesel  Individual
#
#   transmission         owner
# 0       Manual   First Owner
# 1       Manual   First Owner
# 2       Manual   First Owner
# 3       Manual   First Owner
# 4       Manual  Second Owner

# %%
df.columns
# Out:
# Index(['brand_name', 'car_name', 'year', 'selling_price', 'km_driven', 'fuel',
#        'seller_type', 'transmission', 'owner'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of      brand_name car_name  year  selling_price  km_driven    fuel seller_type  \
# 0        Maruti      800  2007          60000      70000  Petrol  Individual
# 1        Maruti    Wagon  2007         135000      50000  Petrol  Individual
# 2       Hyundai    Verna  2012         600000     100000  Diesel  Individual
# 3        Datsun   RediGO  2017         250000      46000  Petrol  Individual
# 4         Honda    Amaze  2014         450000     141000  Diesel  Individual
# ...         ...      ...   ...            ...        ...     ...         ...
# 4335    Hyundai      i20  2014         409999      80000  Diesel  Individual
# 4336    Hyundai      i20  2014         409999      80000  Diesel  Individual
# 4337     Maruti      800  2009         110000      83000  Petrol  Individual
# 4338    Hyundai    Creta  2016         865000      90000  Diesel  Individual
# 4339    Renault     KWID  2016         225000      40000  Petrol  Individual
#
#      transmission         owner
# 0          Manual   First Owner
# 1          Manual   First Owner
# 2          Manual   First Owner
# 3          Manual   First Owner
# 4          Manual  Second Owner
# ...           ...           ...
# 4335       Manual  Second Owner
# 4336       Manual  Second Owner
# 4337       Manual  Second Owner
# 4338       Manual   First Owner
# 4339       Manual   First Owner
#
# [4340 rows x 9 columns]>

# %% [markdown]
# ### Let's start trying to find out What is the most sold car

# %%
df["brand_name"].value_counts(normalize = True)[:5].plot(kind = 'bar') 

plt.show()

# %% [markdown]
# ### show by bar graph  the average Selling prices of all typeof brands

# %%
#we use groupby and mean to extract values and plot to draw the graph

price = df.groupby([df["brand_name"]])[['selling_price']].mean()

price.sort_values(by='selling_price', ascending=True, inplace=True)

ax = price.plot(kind='barh', cmap='PRGn' , figsize=(10,16) ,title= 'Avarege Selling Price Car Brand')
for c in ax.containers: # set the bar label
      ax.bar_label(c, fmt='%.0f',label_type='center', color='w',rotation=0)

# %% [markdown]
# ### We will display a graph to display sales

# %%
## We will display sales by count in pie graphs

labels = df["brand_name"][:20].value_counts().index # We chose only twenty

sizes = df["brand_name"][:20].value_counts()

data = df.groupby(["brand_name"])["brand_name"].count().sort_values(ascending=False) # to extract the count

x = data.index # to extract the brand name
y = data.values # to extract the count to brand 

colors = ['#F8EEFB','#66b3ff','#8000FF','#ffcc99',"#00FF1B","#FF8040","#F8AEF8"]#color choice

plt.figure(figsize = (8,8)) # Determine the size of the graph

# Creating explode data

# explode = (0.1, 0.0, 0.2, 0.3, 0.0, 0.0)

plt.pie(sizes, labels=labels, rotatelabels=False, autopct='%1.1f%%',colors=colors,shadow=True, startangle=45)#Fomat pie
plt.title('name',color = 'black',fontsize = 15) # Fomat title

# plt.legend() <br>

plt.legend(title = "Cars") # title legend

# plt.legend(wedges, cars, title ="Cars",loc ="center left",bbox_to_anchor =(1, 0, 0.5, 1))
# myexplode = [0.2, 0, 0, 0]
plt.show() # view

# %% [markdown]
# ### We see that from the above pie chart the most seller of car brand is "MARUTI" which the 35% persent of whole selling. This selling is about all the year so to see more information about selling we now check the year selling

# %% [markdown]
# ### See the yearwise selling count of all cars

# %%
df.year.value_counts()
# Out:
# 2017    466
# 2015    421
# 2012    415
# 2013    386
# 2014    367
# 2018    366
# 2016    357
# 2011    271
# 2010    234
# 2019    195
# 2009    193
# 2008    145
# 2007    134
# 2006    110
# 2005     85
# 2020     48
# 2004     42
# 2003     23
# 2002     21
# 2001     20
# 1998     12
# 2000     12
# 1999     10
# 1997      3
# 1996      2
# 1995      1
# 1992      1
# Name: year, dtype: int64

# %% [markdown]
# ## Using seaborn the graph show every year of selling car of all car brand

# %%
sns.countplot(data=df,x="year")
plt.xticks(rotation=90)
plt.xlabel("YEAR",fontsize=10,color="forestgreen")
plt.ylabel("COUNT",fontsize=10,color="brown")
plt.title("YEAR COUNT")
plt.grid()
plt.show()

# %% [markdown]
# ### Another graph to view sales classified by fuel
# ### We will display bar graphs

# %%
df["fuel"].value_counts(sort =True).plot(kind="bar", color=["green"])
plt.figsize=(8, 4)

# %% [markdown]
# ## Now see the seller view of sellertype by graph

# %%
df["seller_type"].value_counts(sort = True).plot(kind="bar", color=["green"], figsize=(8, 4) , title='Seller type')
plt.show()

# %% [markdown]
# ### Now see the Transmission by graph

# %%
df["transmission"].value_counts(sort = True).plot(kind="bar", color=["green"], figsize=(8, 4) , title='Transmission')
plt.show()

# %%
df["owner"].value_counts(sort = True).plot(kind="bar", color=["green"], figsize=(8, 4) , title='Owner')
plt.show()

# %% [markdown]
# ## Use line plot to show the price trend over the year passing

# %%
def line_plot(data, title ,xlabel, ylabel):
    plt.figure(figsize=(8, 4))
    sns.lineplot(data=data , palette="tab10", linewidth=3.0)
    plt.title(title, fontsize=12)
    plt.ylabel(ylabel, size=14)
    plt.xlabel(xlabel, size=16)
    
df_price_move = df.groupby(['year'])[['selling_price']].mean()
line_plot(df_price_move,'Price Move', 'Year', "Price")

# %% [markdown]
# #### We are able to see in line graph that as passes the year the price of cars was also increased but at last year it goes down

# %% [markdown]
# ### This graph shows relations between price and km_driven a car

# %%
df.plot(x="km_driven", y="selling_price", kind="scatter", figsize=(8, 4), title="Price & km_driven", color="green");

# %% [markdown]
# ### The relationship between km_driven and year by scatter plot

# %%
df.plot(x="year", y="km_driven", kind="scatter", figsize=(8, 4), title="Year", color="green");

# %% [markdown]
# ## These are some different graphs are shown from above we can easily undestand about data now see the relation between different fators using correlation funtion

# %%
df.corr()
# Out:
#                    year  selling_price  km_driven
# year           1.000000       0.413922  -0.419688
# selling_price  0.413922       1.000000  -0.192289
# km_driven     -0.419688      -0.192289   1.000000

# %%
corr = df.corr()
corr = corr['selling_price']
corr = corr.sort_values(ascending=False)
sns.heatmap(df.corr(), annot=True)
plt.show()

# %% [markdown]
# The heatmap shows a positive correlation between the "year" and "price" variables. As the year increases, the price tends to increase as well.This means that newer cars generally have higher prices compared to older cars.
# The intensity of the positive correlation is depicted by the color gradient in the heatmap, where darker shades indicate a stronger positive correlation.
#
# Negative correlation between kilometers driven and price:
#
# The heatmap reveals a negative correlation between the "kilometers driven" and "price" variables. When the number of kilometers driven increases, the price tends to decrease.
# This implies that cars with higher mileage are typically priced lower compared to cars with lower mileage. The intensity of the negative correlation is depicted by the color gradient in the heatmap, with darker shades indicating a stronger negative correlation.

# %% [markdown]
# ## Now i use for loop

# %%
for i in df.year.unique():
    sns.lmplot(x='km_driven', y='selling_price', data=df[(df.year==i)])
    plt.ticklabel_format(style='plain', axis='y')
    plt.title(f'Year: {i}')

# %% [markdown]
# #### The plot which i used in for loop is lmplot from seaborn and this all plot show that year wise car selling price and the car drive on that year

# %% [markdown]
# ## Here i am using pycaret library to see rought idea about highest accuracy of which ml algorithm

# %%
from pycaret.regression import *

# %%
# Initialize the regression setup

reg_setup = setup(data=df, target='selling_price', session_id=123)

# Compare models and select the best one

best_model = compare_models()

print(best_model)
# Out:
# <style type="text/css">
# #T_dbbb8_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_dbbb8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dbbb8_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_dbbb8_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dbbb8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dbbb8_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_dbbb8_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_dbbb8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dbbb8_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_dbbb8_row1_col1" class="data row1 col1" >selling_price</td>
#     </tr>
#     <tr>
#       <th id="T_dbbb8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dbbb8_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_dbbb8_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_dbbb8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_dbbb8_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_dbbb8_row3_col1" class="data row3 col1" >(4340, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_dbbb8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_dbbb8_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_dbbb8_row4_col1" class="data row4 col1" >(4340, 19)</td>
#     </tr>
#     <tr>
#       <th id="T_dbbb8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_dbbb8_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_dbbb8_row5_col1" class="data row5 col1" >(3038, 19)</td>
#     </tr>
#     <tr>
#       <th id="T_dbbb8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_dbbb8_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_dbbb8_row6_col1" class="data row6 col1" >(1302, 19)</td>
#     </tr>
#     <tr>
#       <th id="T_dbbb8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_dbbb8_row7_col0" class="data row7 col0" >Ordinal features</td>
#       <td id="T_dbbb8_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_dbbb8_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_dbbb8_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_dbbb8_row8_col1" class="data row8 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_dbbb8_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_dbbb8_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_dbbb8_row9_col1" class="data row9 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_dbbb8_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_dbbb8_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_dbbb8_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_dbbb8_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_dbbb8_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_dbbb8_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_dbbb8_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_dbbb8_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_dbbb8_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_dbbb8_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_dbbb8_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_dbbb8_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_dbbb8_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_dbbb8_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_dbbb8_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_dbbb8_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_dbbb8_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_dbbb8_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_dbbb8_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_dbbb8_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_dbbb8_row16_col1" class="data row16 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_dbbb8_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_dbbb8_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_dbbb8_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_dbbb8_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_dbbb8_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_dbbb8_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_dbbb8_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_dbbb8_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_dbbb8_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_dbbb8_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_dbbb8_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_dbbb8_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_dbbb8_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_dbbb8_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_dbbb8_row21_col1" class="data row21 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_dbbb8_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_dbbb8_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_dbbb8_row22_col1" class="data row22 col1" >4bf2</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_287c4 th {
#   text-align: left;
# }
# #T_287c4_row0_col0, #T_287c4_row0_col5, #T_287c4_row1_col0, #T_287c4_row1_col1, #T_287c4_row1_col2, #T_287c4_row1_col3, #T_287c4_row1_col4, #T_287c4_row1_col6, #T_287c4_row2_col0, #T_287c4_row2_col1, #T_287c4_row2_col2, #T_287c4_row2_col3, #T_287c4_row2_col4, #T_287c4_row2_col5, #T_287c4_row2_col6, #T_287c4_row3_col0, #T_287c4_row3_col1, #T_287c4_row3_col2, #T_287c4_row3_col3, #T_287c4_row3_col4, #T_287c4_row3_col5, #T_287c4_row3_col6, #T_287c4_row4_col0, #T_287c4_row4_col1, #T_287c4_row4_col2, #T_287c4_row4_col3, #T_287c4_row4_col4, #T_287c4_row4_col5, #T_287c4_row4_col6, #T_287c4_row5_col0, #T_287c4_row5_col1, #T_287c4_row5_col2, #T_287c4_row5_col3, #T_287c4_row5_col4, #T_287c4_row5_col5, #T_287c4_row5_col6, #T_287c4_row6_col0, #T_287c4_row6_col1, #T_287c4_row6_col2, #T_287c4_row6_col3, #T_287c4_row6_col4, #T_287c4_row6_col5, #T_287c4_row6_col6, #T_287c4_row7_col0, #T_287c4_row7_col1, #T_287c4_row7_col2, #T_287c4_row7_col3, #T_287c4_row7_col4, #T_287c4_row7_col5, #T_287c4_row7_col6, #T_287c4_row8_col0, #T_287c4_row8_col1, #T_287c4_row8_col2, #T_287c4_row8_col3, #T_287c4_row8_col4, #T_287c4_row8_col5, #T_287c4_row8_col6, #T_287c4_row9_col0, #T_287c4_row9_col1, #T_287c4_row9_col2, #T_287c4_row9_col3, #T_287c4_row9_col4, #T_287c4_row9_col5, #T_287c4_row9_col6, #T_287c4_row10_col0, #T_287c4_row10_col1, #T_287c4_row10_col2, #T_287c4_row10_col3, #T_287c4_row10_col4, #T_287c4_row10_col5, #T_287c4_row10_col6, #T_287c4_row11_col0, #T_287c4_row11_col1, #T_287c4_row11_col2, #T_287c4_row11_col3, #T_287c4_row11_col4, #T_287c4_row11_col5, #T_287c4_row11_col6, #T_287c4_row12_col0, #T_287c4_row12_col1, #T_287c4_row12_col2, #T_287c4_row12_col3, #T_287c4_row12_col4, #T_287c4_row12_col5, #T_287c4_row12_col6, #T_287c4_row13_col0, #T_287c4_row13_col1, #T_287c4_row13_col2, #T_287c4_row13_col3, #T_287c4_row13_col4, #T_287c4_row13_col5, #T_287c4_row13_col6, #T_287c4_row14_col0, #T_287c4_row14_col1, #T_287c4_row14_col2, #T_287c4_row14_col3, #T_287c4_row14_col4, #T_287c4_row14_col5, #T_287c4_row14_col6, #T_287c4_row15_col0, #T_287c4_row15_col1, #T_287c4_row15_col2, #T_287c4_row15_col3, #T_287c4_row15_col4, #T_287c4_row15_col5, #T_287c4_row15_col6, #T_287c4_row16_col0, #T_287c4_row16_col1, #T_287c4_row16_col2, #T_287c4_row16_col3, #T_287c4_row16_col4, #T_287c4_row16_col5, #T_287c4_row16_col6, #T_287c4_row17_col0, #T_287c4_row17_col1, #T_287c4_row17_col2, #T_287c4_row17_col3, #T_287c4_row17_col4, #T_287c4_row17_col5, #T_287c4_row17_col6 {
#   text-align: left;
# }
# #T_287c4_row0_col1, #T_287c4_row0_col2, #T_287c4_row0_col3, #T_287c4_row0_col4, #T_287c4_row0_col6, #T_287c4_row1_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_287c4_row0_col7, #T_287c4_row1_col7, #T_287c4_row2_col7, #T_287c4_row3_col7, #T_287c4_row4_col7, #T_287c4_row5_col7, #T_287c4_row6_col7, #T_287c4_row7_col7, #T_287c4_row8_col7, #T_287c4_row9_col7, #T_287c4_row10_col7, #T_287c4_row12_col7, #T_287c4_row13_col7, #T_287c4_row14_col7, #T_287c4_row15_col7, #T_287c4_row16_col7, #T_287c4_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_287c4_row11_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_287c4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_287c4_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_287c4_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_287c4_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_287c4_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_287c4_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_287c4_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_287c4_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_287c4_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_287c4_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_287c4_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_287c4_row0_col1" class="data row0 col1" >83623.0201</td>
#       <td id="T_287c4_row0_col2" class="data row0 col2" >46537892915.6368</td>
#       <td id="T_287c4_row0_col3" class="data row0 col3" >205177.6987</td>
#       <td id="T_287c4_row0_col4" class="data row0 col4" >0.8616</td>
#       <td id="T_287c4_row0_col5" class="data row0 col5" >0.2743</td>
#       <td id="T_287c4_row0_col6" class="data row0 col6" >0.1969</td>
#       <td id="T_287c4_row0_col7" class="data row0 col7" >0.8520</td>
#     </tr>
#     <tr>
#       <th id="T_287c4_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_287c4_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_287c4_row1_col1" class="data row1 col1" >85824.2554</td>
#       <td id="T_287c4_row1_col2" class="data row1 col2" >50833107784.0076</td>
#       <td id="T_287c4_row1_col3" class="data row1 col3" >214060.9967</td>
#       <td id="T_287c4_row1_col4" class="data row1 col4" >0.8491</td>
#       <td id="T_287c4_row1_col5" class="data row1 col5" >0.2647</td>
#       <td id="T_287c4_row1_col6" class="data row1 col6" >0.1985</td>
#       <td id="T_287c4_row1_col7" class="data row1 col7" >0.7620</td>
#     </tr>
#     <tr>
#       <th id="T_287c4_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_287c4_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_287c4_row2_col1" class="data row2 col1" >93101.3071</td>
#       <td id="T_287c4_row2_col2" class="data row2 col2" >51384097369.9114</td>
#       <td id="T_287c4_row2_col3" class="data row2 col3" >215788.5566</td>
#       <td id="T_287c4_row2_col4" class="data row2 col4" >0.8462</td>
#       <td id="T_287c4_row2_col5" class="data row2 col5" >0.2765</td>
#       <td id="T_287c4_row2_col6" class="data row2 col6" >0.2164</td>
#       <td id="T_287c4_row2_col7" class="data row2 col7" >0.8490</td>
#     </tr>
#     <tr>
#       <th id="T_287c4_level0_row3" class="row_heading level0 row3" >gbr</th>
#       <td id="T_287c4_row3_col0" class="data row3 col0" >Gradient Boosting Regressor</td>
#       <td id="T_287c4_row3_col1" class="data row3 col1" >102409.5070</td>
#       <td id="T_287c4_row3_col2" class="data row3 col2" >53297827796.6111</td>
#       <td id="T_287c4_row3_col3" class="data row3 col3" >220708.1931</td>
#       <td id="T_287c4_row3_col4" class="data row3 col4" >0.8409</td>
#       <td id="T_287c4_row3_col5" class="data row3 col5" >0.3070</td>
#       <td id="T_287c4_row3_col6" class="data row3 col6" >0.2481</td>
#       <td id="T_287c4_row3_col7" class="data row3 col7" >0.6750</td>
#     </tr>
#     <tr>
#       <th id="T_287c4_level0_row4" class="row_heading level0 row4" >dt</th>
#       <td id="T_287c4_row4_col0" class="data row4 col0" >Decision Tree Regressor</td>
#       <td id="T_287c4_row4_col1" class="data row4 col1" >98424.4037</td>
#       <td id="T_287c4_row4_col2" class="data row4 col2" >60090361719.7944</td>
#       <td id="T_287c4_row4_col3" class="data row4 col3" >237174.9700</td>
#       <td id="T_287c4_row4_col4" class="data row4 col4" >0.8141</td>
#       <td id="T_287c4_row4_col5" class="data row4 col5" >0.3256</td>
#       <td id="T_287c4_row4_col6" class="data row4 col6" >0.2248</td>
#       <td id="T_287c4_row4_col7" class="data row4 col7" >0.6120</td>
#     </tr>
#     <tr>
#       <th id="T_287c4_level0_row5" class="row_heading level0 row5" >knn</th>
#       <td id="T_287c4_row5_col0" class="data row5 col0" >K Neighbors Regressor</td>
#       <td id="T_287c4_row5_col1" class="data row5 col1" >132399.2124</td>
#       <td id="T_287c4_row5_col2" class="data row5 col2" >86532407520.7036</td>
#       <td id="T_287c4_row5_col3" class="data row5 col3" >287715.6749</td>
#       <td id="T_287c4_row5_col4" class="data row5 col4" >0.7322</td>
#       <td id="T_287c4_row5_col5" class="data row5 col5" >0.4042</td>
#       <td id="T_287c4_row5_col6" class="data row5 col6" >0.3442</td>
# Processing:   0%|          | 0/77 [00:00<?, ?it/s]
# ExtraTreesRegressor(n_jobs=-1, random_state=123)

# %% [markdown]
# ## Splitting the dataset to train and test data

# %%
x = df.drop('selling_price', axis=1)
y = df['selling_price']

print(type(x))
print(type(y))

print(x.shape)
print(y.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>
# (4340, 8)
# (4340,)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 1)

print(x_train.shape)
print(x_test.shape)

print(y_train.shape)
print(y_test.shape)
# Out:
# (3255, 8)
# (1085, 8)
# (3255,)
# (1085,)

# %% [markdown]
# ## Defining all funtion in one class

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Function for Regression Evaluation Metrics

test = {'Model' : [], 'MAE' : [], 'MSE' : [], 'R2Score' : []}
def eval_model(model_name, y, ypred) :
    mae = mean_absolute_error(y, ypred)
    mse = mean_squared_error(y, ypred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y, ypred)
    print('Mean Absolute Error', mae)
    print('Mean Squared Error', mse)
    print('Root Mean Squared Error', rmse)
    print('R2 Score', r2)
    test['Model'].append(model_name)
    test['MAE'].append(mae)
    test['MSE'].append(mse)
    test['R2Score'].append(r2)

# %% [markdown]
# ## Importing all major library

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge, Lasso
from sklearn.neighbors import KNeighborsRegressor 
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %%
x.head()
# Out:
#   brand_name car_name  year  km_driven    fuel seller_type transmission  \
# 0     Maruti      800  2007      70000  Petrol  Individual       Manual
# 1     Maruti    Wagon  2007      50000  Petrol  Individual       Manual
# 2    Hyundai    Verna  2012     100000  Diesel  Individual       Manual
# 3     Datsun   RediGO  2017      46000  Petrol  Individual       Manual
# 4      Honda    Amaze  2014     141000  Diesel  Individual       Manual
#
#           owner
# 0   First Owner
# 1   First Owner
# 2   First Owner
# 3   First Owner
# 4  Second Owner

# %% [markdown]
# ## 1) Lasso

# %%
model = ColumnTransformer(transformers=
                         [('col_transf', OneHotEncoder(handle_unknown='ignore',drop = 'first', sparse=False), [0,1,4,5,6,7])],
                         remainder='passthrough')
model1 = Lasso(alpha=0.1)
pipe_lasso = Pipeline([('model', model), ('model1', model1)])
pipe_lasso.fit(x_train, y_train)

ypred_lasso = pipe_lasso.predict(x_test)

eval_model('Lasso Regression', y_test, ypred_lasso)
# Out:
# Mean Absolute Error 125171.90610720348
# Mean Squared Error 84814488280.77797
# Root Mean Squared Error 291229.270988989
# R2 Score 0.7569399399435678

# %% [markdown]
# ## 2) Linear Regression

# %%
model = ColumnTransformer(transformers=
                         [('col_transf', OneHotEncoder(handle_unknown='ignore',drop = 'first', sparse=False), [0,1,4,5,6,7])],
                         remainder='passthrough')
model2 = LinearRegression()
pipe_lr = Pipeline([('model', model), ('model2', model2)])
pipe_lr.fit(x_train, y_train)

ypred_lr = pipe_lr.predict(x_test)

eval_model('Linear Regression', y_test, ypred_lr)
# Out:
# Mean Absolute Error 4047367428.1173377
# Mean Squared Error 3.025069576884632e+21
# Root Mean Squared Error 55000632513.49599
# R2 Score -8669198009.112906

# %% [markdown]
# ## 3) Ridge

# %%
model= ColumnTransformer(transformers=
                         [('col_transf', OneHotEncoder(handle_unknown='ignore',drop = 'first', sparse=False), [0,1,4,5,6,7])],
                         remainder='passthrough')
model3 = Ridge(alpha=10)
pipe_ridge = Pipeline([('model', model), ('model3', model3)])
pipe_ridge.fit(x_train, y_train)

ypred_ridge = pipe_ridge.predict(x_test)

eval_model('Ridge Regression', y_test, ypred_ridge)
# Out:
# Mean Absolute Error 147451.39643583508
# Mean Squared Error 87884178174.47527
# Root Mean Squared Error 296452.6575601495
# R2 Score 0.7481428697136954

# %% [markdown]
# ## 4) Decision Tree Regressor

# %%
model = ColumnTransformer(transformers=
                         [('col_transf', OneHotEncoder(handle_unknown='ignore',drop = 'first', sparse=False), [0,1,4,5,6,7])],
                         remainder='passthrough')

model4 = DecisionTreeRegressor(max_depth=8, min_samples_split=15)
pipe_dt = Pipeline([('model', model), ('model4',model4)])
pipe_dt.fit(x_train, y_train)

ypred_dt = pipe_dt.predict(x_test)

eval_model('Decision Tree Regressor', y_test, ypred_dt)
# Out:
# Mean Absolute Error 152202.27628201945
# Mean Squared Error 90588054316.193
# Root Mean Squared Error 300978.49477361835
# R2 Score 0.7403941429252322

# %% [markdown]
# ## 5) Random Forest Regressor

# %%
model = ColumnTransformer(transformers=
                         [('col_transf', OneHotEncoder(handle_unknown='ignore',drop = 'first', sparse=False), [0,1,4,5,6,7])],
                         remainder='passthrough')

model5 = RandomForestRegressor(n_estimators=100,max_depth=16, min_samples_split=15, random_state=11)
pipe_rf = Pipeline([('model', model), ('model5', model5)])
pipe_rf.fit(x_train, y_train)

ypred_rf = pipe_rf.predict(x_test)

eval_model('Random Forest Regressor', y_test, ypred_rf)
# Out:
# Mean Absolute Error 105043.22961224182
# Mean Squared Error 65265356211.82438
# Root Mean Squared Error 255470.8519808559
# R2 Score 0.8129635428803772

# %% [markdown]
# ## 6) Extra Trees Regressor

# %%
from sklearn.tree import ExtraTreeRegressor

# %%
from sklearn.ensemble import ExtraTreesRegressor

model = ColumnTransformer(transformers=
                         [('col_transf', OneHotEncoder(handle_unknown='ignore',drop = 'first', sparse=False), [0,1,4,5,6,7])],
                         remainder='passthrough')

model6 = ExtraTreesRegressor(n_estimators=100,max_depth=16, min_samples_split=20, random_state=25)
pipe_rf = Pipeline([('model', model), ('model6', model6)])
pipe_rf.fit(x_train, y_train)

ypred_rf = pipe_rf.predict(x_test)

eval_model('Extra Trees Regressor', y_test, ypred_rf)
# Out:
# Mean Absolute Error 105240.00535355463
# Mean Squared Error 73179646093.83725
# Root Mean Squared Error 270517.36745325103
# R2 Score 0.7902828922861316

# %% [markdown]
# #### i used 7 different - different ML model to see the which provide the high accuracy so that the random dorest regressor and Extra trees regressor both provide estimatly nearly accuracy so that i choose random forest regressor for the best model and save this model

# %% [markdown]
# #  Save The Model

# %%
import pickle

# %%
pickle.dump(pipe_rf, open('car_prediction.pkl', 'wb'))    # Saving the best performing model
pickle.dump(df, open('data.pkl', 'wb'))

# %% [markdown]
# # Load the Model

# %%
loaded_model = pickle.load(open('car_prediction.pkl', 'rb'))

# %% [markdown]
# ## Performing the model on 20 randomly selected data points

# %%
df_random_sample =df.sample(20)
df_random_sample.head()
# Out:
#      brand_name  car_name  year  selling_price  km_driven    fuel seller_type  \
# 527      Toyota  Fortuner  2017        2750000      41000  Diesel  Individual
# 2524       Tata    Indigo  2015         225000      68745  Diesel      Dealer
# 1109     Maruti      Omni  2016         120000     120000  Petrol  Individual
# 2686    Hyundai       i10  2010         125000      60000  Petrol  Individual
# 3491    Hyundai       i20  2012         250000      70000  Diesel  Individual
#
#      transmission        owner
# 527     Automatic  First Owner
# 2524       Manual  First Owner
# 1109       Manual  First Owner
# 2686       Manual  Third Owner
# 3491       Manual  First Owner

# %%
df_sample =df_random_sample.to_csv("car_details_sample_data")

# %%
df_random_sample.shape
# Out:
# (20, 9)

# %%
new_x = df_random_sample.drop('selling_price', axis=1)
new_ytest =df_random_sample['selling_price']
print(new_x.shape)

best_pred = loaded_model.predict(new_x)
print(eval_model('Best Model', new_ytest, best_pred))
best_pred
# Out:
# (20, 8)
# Mean Absolute Error 87974.95811507203
# Mean Squared Error 16631009589.693832
# Root Mean Squared Error 128961.27166593012
# R2 Score 0.9454076512160138
# None
# array([2694297.56410257,  297994.03016496,  227787.82169913,
#         175599.86422119,  338875.87959608,  309418.10041351,
#         186050.12714788,  246644.81366381,  317848.61961024,
#        1103292.59565616,  474646.32157935,  157729.61767785,
#         279948.20459211,  315256.36982151,  635365.10369866,
#         658712.35405672,  431548.16263902,  478607.3498698 ,
#        1002336.6565707 ,  740968.8810968 ])

# %% [markdown]
# ### The accuracy of sample data is good after choosing 20 sample point from dataset and it is best model for it.
